# %%
import pandas as pd

orders = pd.read_csv('/content/orders.csv')
order_items = pd.read_csv('/content/order_items.csv')

# %%
orders.head()
# Out:
#    order_id  user_id     status gender               created_at returned_at  \
# 0         1        2  Cancelled      F  2021-09-06 07:28:00 UTC         NaN
# 1        39       32  Cancelled      F  2020-10-11 15:42:00 UTC         NaN
# 2        48       37  Cancelled      F  2021-12-05 09:25:00 UTC         NaN
# 3        80       56  Cancelled      F  2022-04-22 03:59:00 UTC         NaN
# 4        82       57  Cancelled      F  2023-02-20 11:11:00 UTC         NaN
#
#   shipped_at delivered_at  num_of_item
# 0        NaN          NaN            3
# 1        NaN          NaN            1
# 2        NaN          NaN            1
# 3        NaN          NaN            1
# 4        NaN          NaN            1

# %%
print(orders.isnull().sum())
# Out:
# order_id            0
# user_id             0
# status              0
# gender              0
# shipped_at      20804
# delivered_at    57508
# num_of_item         0
# dtype: int64

# %%
order_items.head()
# Out:
#        id  order_id  user_id  product_id  inventory_item_id    status  \
# 0  164929    113613    90947       14235             445280  Complete
# 1  164210    113106    90556       14235             443365  Returned
# 2   98533     67868    54319       14235             265968   Shipped
# 3   10097      6887     5414       14159              27113  Complete
# 4  102997     70949    56842       14159             278065  Complete
#
#                 shipped_at             delivered_at  sale_price
# 0  2022-01-24 09:56:00 UTC  2022-01-24 10:42:00 UTC        0.02
# 1  2024-01-02 05:57:00 UTC  2024-01-05 19:37:00 UTC        0.02
# 2  2023-07-23 01:25:00 UTC                      NaN        0.02
# 3  2023-12-06 07:22:00 UTC  2023-12-07 11:04:00 UTC        0.49
# 4  2024-03-27 04:12:00 UTC  2024-03-30 07:34:00 UTC        0.49

# %%
print(order_items.isnull().sum())
# Out:
# id                        0
# order_id                  0
# user_id                   0
# product_id                0
# inventory_item_id         0
# status                    0
# shipped_at            63318
# delivered_at         118130
# sale_price                0
# dtype: int64

# %%
unique_statuses = orders['status'].unique()
print(unique_statuses)
# Out:
# ['Cancelled' 'Complete' 'Processing' 'Returned' 'Shipped']

# %%
orders = orders[orders['status'] != 'Processing']

print(orders['status'].unique())
print(orders.shape)
# Out:
# ['Cancelled' 'Complete' 'Returned' 'Shipped']
# (100012, 9)

# %%
orders = orders.drop(columns=['returned_at'])

# %%
orders = orders.drop(columns=['created_at'])

# %%
order_items.head()
# Out:
#        id  order_id  user_id  product_id  inventory_item_id    status  \
# 0  164929    113613    90947       14235             445280  Complete
# 1  164210    113106    90556       14235             443365  Returned
# 2   98533     67868    54319       14235             265968   Shipped
# 3   10097      6887     5414       14159              27113  Complete
# 4  102997     70949    56842       14159             278065  Complete
#
#                 created_at               shipped_at             delivered_at  \
# 0  2022-01-21 15:04:03 UTC  2022-01-24 09:56:00 UTC  2022-01-24 10:42:00 UTC
# 1  2023-12-31 11:45:54 UTC  2024-01-02 05:57:00 UTC  2024-01-05 19:37:00 UTC
# 2  2023-07-22 03:55:41 UTC  2023-07-23 01:25:00 UTC                      NaN
# 3  2023-12-09 01:36:00 UTC  2023-12-06 07:22:00 UTC  2023-12-07 11:04:00 UTC
# 4  2024-03-24 04:55:16 UTC  2024-03-27 04:12:00 UTC  2024-03-30 07:34:00 UTC
#
#    sale_price
# 0        0.02
# 1        0.02
# 2        0.02
# 3        0.49
# ...

# %%
order_items = order_items.drop(columns=['returned_at'])

# %%
order_items = order_items.drop(columns=['created_at'])

# %%
orders['shipped_at'] = pd.to_datetime(orders['shipped_at'], errors='coerce')
orders['delivered_at'] = pd.to_datetime(orders['delivered_at'], errors='coerce')

# %%
orderorders.to_csv('/content/ordeorders.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-5e43643a7a48> in <cell line: 1>()
# ----> 1 orderorders.to_csv('/content/ordeorders.csv', index=False)
#
# NameError: name 'orderorders' is not defined

# %%
orders_items_outer = pd.merge(orders, order_items, on=['order_id', 'user_id'], how='outer')

orders_items_outer.head()
# Out:
#    order_id  user_id   status_x gender shipped_at_x delivered_at_x  \
# 0         1        2  Cancelled      F          NaT            NaT
# 1         1        2  Cancelled      F          NaT            NaT
# 2         1        2  Cancelled      F          NaT            NaT
# 3        39       32  Cancelled      F          NaT            NaT
# 4        48       37  Cancelled      F          NaT            NaT
#
#    num_of_item  id  product_id  inventory_item_id   status_y shipped_at_y  \
# 0          3.0   1        6972                  2  Cancelled          NaN
# 1          3.0   3        2310                  8  Cancelled          NaN
# 2          3.0   2       10465                  4  Cancelled          NaN
# 3          1.0  52       14224                145  Cancelled          NaN
# 4          1.0  65        8888                182  Cancelled          NaN
#
#   delivered_at_y  sale_price
# 0            NaN   15.000000
# 1            NaN   22.219999
# ...

# %%
                             left_on=['order_id', 'user_id'],
                             right_on=['order_id', 'user_id'],
                             how='left',
                             suffixes=('_item_orders', '_orders'))

# %%
orders_items_outer.rename(columns={'shipped_at_x': 'shipped_at_', 'delivered_at_x': 'delivered_at_'}, inplace=True)

# %%
orders_items_outer = orders_items_outer.drop(columns=['shipped_at_y', "delivered_at_y"])

# %%
orders_items_outer = orders_items_outer.drop(columns=['status_y'])

# %%
print(orders_items_outer.isnull().sum())
# Out:
# order_id                  0
# user_id                   0
# status_x              36235
# gender                36235
# shipped_at_           66308
# delivered_at_        119698
# num_of_item           36235
# id                        0
# product_id                0
# inventory_item_id         0
# sale_price                0
# dtype: int64

# %%
orders_items_outer.to_csv('orders_items_outer.csv', index=False)

# %%
from google.colab import files
files.download('/content/orders_items_outer.csv')

# %%
Inventory = pd.read_csv('/content/Inventory.csv')

# %%
print(Inventory.isnull().sum())
# Out:
# id                                  0
# product_id                          0
# cost                                0
# product_category                    0
# product_name                       38
# product_brand                     433
# product_retail_price                0
# product_department                  0
# product_distribution_center_id      0
# dtype: int64

# %%
Inventory = Inventory.drop(columns=['created_at', "sold_at", "product_sku", "sold_at"])

# %%
orders_items_inv = pd.merge(orders_items_outer, Inventory, on='product_id', how='outer')

print(orders_items_inv.head())
# Out:
#    order_id  user_id   status_x gender shipped_at_ delivered_at_  num_of_item  \
# 0         1        2  Cancelled      F         NaT           NaT          3.0
# 1         1        2  Cancelled      F         NaT           NaT          3.0
# 2         1        2  Cancelled      F         NaT           NaT          3.0
# 3         1        2  Cancelled      F         NaT           NaT          3.0
# 4         1        2  Cancelled      F         NaT           NaT          3.0
#
#    id_x  product_id  inventory_item_id  sale_price   id_y  cost  \
# 0     1        6972                  2        15.0      1  7.23
# 1     1        6972                  2        15.0      2  7.23
# 2     1        6972                  2        15.0  94795  7.23
# 3     1        6972                  2        15.0  94796  7.23
# 4     1        6972                  2        15.0  94797  7.23
#
#   product_category                                       product_name  \
# ...

# %%
selected_columns = orders_items_inv[['id_x', 'id_y']]

print(selected_columns.head())
# Out:
#    id_x   id_y
# 0     1      1
# 1     1      2
# 2     1  94795
# 3     1  94796
# 4     1  94797

# %%
print(orders_items_inv.isnull().sum())
# Out:
# order_id                             0
# user_id                              0
# status_x                             0
# gender                               0
# shipped_at_                          0
# delivered_at_                        0
# num_of_item                          0
# id_x                                 0
# product_id                           0
# inventory_item_id                    0
# sale_price                           0
# id_y                                 0
# cost                                 0
# product_category                     0
# product_name                       110
# product_brand                     1233
# product_retail_price                 0
# product_department                   0
# product_distribution_center_id       0
# id                                   0
# name                                 0
# latitude                             0
# longitude                            0
# dtype: int64

# %%
orders_items_inv = orders_items_inv.dropna(subset=['shipped_at_', 'delivered_at_'])

print(orders_items_inv.shape)

orders_items_inv.head()

print(orders_items_inv.isnull().sum())
# Out:
# (1216595, 23)
# order_id                             0
# user_id                              0
# status_x                             0
# gender                               0
# shipped_at_                          0
# delivered_at_                        0
# num_of_item                          0
# id_x                                 0
# product_id                           0
# inventory_item_id                    0
# sale_price                           0
# id_y                                 0
# cost                                 0
# product_category                     0
# product_name                       110
# product_brand                     1233
# product_retail_price                 0
# product_department                   0
# product_distribution_center_id       0
# id                                   0
# name                                 0
# latitude                             0
# longitude                            0
# dtype: int64

# %%
orders_items_inv = orders_items_inv.dropna(subset=['id_x','id_y'])

# %%
orders_items_inv.to_csv('orders_items_inv.csv', index=False)

# %%
from google.colab import files
files.download('/content/orders_items_inv.csv')

# %%
distribution_centers = pd.read_csv('/content/distribution_centers.csv')
distribution_centers.head()
# Out:
#    id            name  latitude  longitude
# 0   1      Memphis TN   35.1174   -89.9711
# 1   2      Chicago IL   41.8369   -87.6847
# 2   3      Houston TX   29.7604   -95.3698
# 3   4  Los Angeles CA   34.0500  -118.2500
# 4   5  New Orleans LA   29.9500   -90.0667

# %%
orders_items_with_dist = pd.merge(orders_items_inv, distribution_centers, left_on='product_distribution_center_id', right_on='id', how='outer')

orders_items_with_dist.head()
# Out:
#    order_id  user_id   status_x gender shipped_at_ delivered_at_  num_of_item  \
# 0         1        2  Cancelled      F         NaT           NaT          3.0
# 1         1        2  Cancelled      F         NaT           NaT          3.0
# 2         1        2  Cancelled      F         NaT           NaT          3.0
# 3         1        2  Cancelled      F         NaT           NaT          3.0
# 4         1        2  Cancelled      F         NaT           NaT          3.0
#
#    id_x  product_id  inventory_item_id  ...  product_category  \
# 0     1        6972                  2  ...            Shorts
# 1     1        6972                  2  ...            Shorts
# 2     1        6972                  2  ...            Shorts
# 3     1        6972                  2  ...            Shorts
# 4     1        6972                  2  ...            Shorts
#
#                                         product_name  product_brand  \
# ...

# %%
orders_items_with_dist = orders_items_with_dist.dropna(subset=['id_x', 'id','id_y'])

# %%
orders_items_with_dist.to_csv('orders_items_with_dist.csv', index=False)

# %%
from google.colab import files
files.download('/content/orders_items_with_dist.csv')

# %%
print(orders_items_with_dist.isnull().sum())
# Out:
# order_id                                0
# user_id                                 0
# status_x                           712685
# gender                             712685
# shipped_at_                       1304116
# delivered_at_                     2353187
# num_of_item                        712685
# id_x                                    0
# product_id                              0
# inventory_item_id                       0
# sale_price                              0
# id_y                                    0
# cost                                    0
# product_category                        0
# product_name                          256
# product_brand                        3273
# product_retail_price                    0
# product_department                      0
# product_distribution_center_id          0
# id                                      0
# name                                    0
# latitude                                0
# ...
